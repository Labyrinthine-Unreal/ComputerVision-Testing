# %% [markdown]
# ### AUGMENTING TRAINING/VALIDATION DATA

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import keras 
image = 'clash_data/train/train/TownHall_13/farm/Unnattacked/'
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        #brightness_range=None,
                                                        shear_range=0.02,
                                                        zoom_range=0.2400,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
test_datagen = ImageDataGenerator(rescale=1 / 255.0)
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        #brightness_range=None,
                                                        shear_range=0.02,
                                                        zoom_range=0.2400,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_12/Trophy/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_12/Trophy/Attacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_12/Farm/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_12/Farm/Attacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_12/War/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_12/War/Attacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_12/War/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_12/War/Unattacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()

dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        #brightness_range=None,
                                                        shear_range=0.02,
                                                        zoom_range=0.2400,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_11/Farm/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_11/Farm/Attacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_11/Farm/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_11/Farm/Unattacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_11/War/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_11/War/Attacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_11/War/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_11/War/Unattacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        #brightness_range=None,
                                                        shear_range=0.02,
                                                        zoom_range=0.2400,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_10/Farm/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_10/Farm/Unattacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()  
image = dataset.flow_from_directory('clash_data/train/train/TownHall_10/Farm/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_10/Farm/Attacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_10/Trophy/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_10/Trophy/Unattacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_10/Trophy/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_10/Trophy/Attacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
# dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
#                                                         rotation_range=90,
#                                                         width_shift_range=0.0045,
#                                                         height_shift_range=0.015,
#                                                         #brightness_range=None,
#                                                         shear_range=0.02,
#                                                         zoom_range=0.2400,
#                                                         channel_shift_range=0.0,
#                                                         fill_mode="nearest",
#                                                         cval=0.0,
#                                                         horizontal_flip=True,
#                                                         vertical_flip=True,
#                                                         rescale= 1./255,
#                                                         preprocessing_function=None,
#                                                         data_format=None,
#                                                         validation_split=0.25,
#                                                         dtype=None,)
# image = dataset.flow_from_directory('clash_data/train/train/TownHall_9/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_9',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
# #image.next()
# dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
#                                                         rotation_range=90,
#                                                         width_shift_range=0.0045,
#                                                         height_shift_range=0.015,
#                                                         #brightness_range=None,
#                                                         shear_range=0.02,
#                                                         zoom_range=0.2400,
#                                                         channel_shift_range=0.0,
#                                                         fill_mode="nearest",
#                                                         cval=0.0,
#                                                         horizontal_flip=True,
#                                                         vertical_flip=True,
#                                                         rescale= 1./255,
#                                                         preprocessing_function=None,
#                                                         data_format=None,
#                                                         validation_split=0.25,
#                                                         dtype=None,)
# image = dataset.flow_from_directory('clash_data/train/train/TownHall_8/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_8',class_mode='binary',save_prefix='deck1',save_format='jpg',batch_size=25)
# #image.next()
# dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
#                                                         rotation_range=90,
#                                                         width_shift_range=0.0045,
#                                                         height_shift_range=0.015,
#                                                         #brightness_range=None,
#                                                         shear_range=0.02,
#                                                         zoom_range=0.2400,
#                                                         channel_shift_range=0.0,
#                                                         fill_mode="nearest",
#                                                         cval=0.0,
#                                                         horizontal_flip=True,
#                                                         vertical_flip=True,
#                                                         rescale= 1./255,
#                                                         preprocessing_function=None,
#                                                         data_format=None,
#                                                         validation_split=0.25,
#                                                         dtype=None,)
# image = dataset.flow_from_directory('clash_data/train/train/TownHall_7/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_7',class_mode='binary',save_prefix='deck1',save_format='jpg',batch_size=25)
# #image.next()
# dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
#                                                         rotation_range=90,
#                                                         width_shift_range=0.0045,
#                                                         height_shift_range=0.015,
#                                                         #brightness_range=None,
#                                                         shear_range=0.02,
#                                                         zoom_range=0.2400,
#                                                         channel_shift_range=0.0,
#                                                         fill_mode="nearest",
#                                                         cval=0.0,
#                                                         horizontal_flip=True,
#                                                         vertical_flip=True,
#                                                         rescale= 1./255,
#                                                         preprocessing_function=None,
#                                                         data_format=None,
#                                                         validation_split=0.25,
#                                                         dtype=None,)
# image = dataset.flow_from_directory('clash_data/train/train/TownHall_6/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_6',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
# #image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        #brightness_range=None,
                                                        shear_range=0.02,
                                                        zoom_range=0.2400,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/Builder_Hall/BuilderBase_Th9Farm/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/Builder_Hall/BuilderBase_Th9Farm/Attacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
# image = dataset.flow_from_directory('clash_data/train/train/Builder_Hall/BuilderBase_Th8Farm/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/Builder_Hall',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
# #image.next() 
image = dataset.flow_from_directory('clash_data/train/train/Builder_Hall/BuilderBase_Th9Farm/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/Builder_Hall/BuilderBase_Th9Farm/Unattacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
image = dataset.flow_from_directory('clash_data/train/train/Builder_Hall/BuilderBase_Th8Farm/Unnattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/Builder_Hall/BuilderBase_Th8Farm/Unattacked/',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
#image.next()
# dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
#                                                         rotation_range=90,
#                                                         width_shift_range=0.0045,
#                                                         height_shift_range=0.015,
#                                                         #brightness_range=None,
#                                                         shear_range=0.02,
#                                                         zoom_range=0.2400,
#                                                         channel_shift_range=0.0,
#                                                         fill_mode="nearest",
#                                                         cval=0.0,
#                                                         horizontal_flip=True,
#                                                         vertical_flip=True,
#                                                         rescale= 1./255,
#                                                         preprocessing_function=None,
#                                                         data_format=None,
#                                                         validation_split=0.25,
#                                                         dtype=None,)
# image = dataset.flow_from_directory('clash_data/train/train/Fun_Bases/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/Fun_Bases',class_mode='binary',save_prefix='clash_',save_format='jpg',batch_size=25)
# #image.next()
# Out:
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.

# %% [markdown]
# ### AUGMENTING TRAINING/TESTING DATA

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img


batch_size = 2000
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=45,
                                                        width_shift_range=0.0.025,
                                                        height_shift_range=0.045,
                                                        brightness_range=None,
                                                        shear_range=0.025,
                                                        zoom_range=0..02200,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,
                                                        dtype=None,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_13/farm/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_13/farm/Attacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_13/farm/Unnattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_13/farm/Unnattacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.015,
                                                        height_shift_range=0.030,
                                                        brightness_range=None,
                                                        shear_range=0.02,
                                                        zoom_range=0.07500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,
                                                        dtype=None,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_12/Trophy/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_12/Trophy/Attacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_12/Farm/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_12/Farm/Attacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_12/War/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_12/War/Attacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_12/War/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_12/War/Unattacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()

dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=15,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        brightness_range=None,
                                                        shear_range=0.0002,
                                                        zoom_range=0.002400,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,
                                                        dtype=None,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_11/Farm/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_11/Farm/Attacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_11/Farm/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_11/Farm/Unattacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_11/War/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_11/War/Attacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_11/War/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_11/War/Unattacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        brightness_range=None,
                                                        shear_range=0.02,
                                                        zoom_range=0.2400,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,
                                                        dtype=None,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_10/Farm/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_10/Farm/Unattacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()  
image = dataset.flow_from_directory('clash_data/train/train/TownHall_10/Farm/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_10/Farm/Attacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_10/Trophy/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_10/Trophy/Attacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
image = dataset.flow_from_directory('clash_data/train/train/TownHall_10/Trophy/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_10/Trophy/Attacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
# dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
#                                                         rotation_range=90,
#                                                         width_shift_range=0.0045,
#                                                         height_shift_range=0.015,
#                                                         brightness_range=None,
#                                                         shear_range=0.02,
#                                                         zoom_range=0.2400,
#                                                         channel_shift_range=0.0,
#                                                         fill_mode="nearest",
#                                                         cval=0.0,
#                                                         horizontal_flip=True,
#                                                         vertical_flip=True,
#                                                         rescale= 1./255,
#                                                         preprocessing_function=None,
#                                                         data_format=None,
#                                                         validation_split=0.25,
#                                                         dtype=None,)
# image = dataset.flow_from_directory('clash_data/train/train/TownHall_9/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_9',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
# image.next()
# dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
#                                                         rotation_range=90,
#                                                         width_shift_range=0.0045,
#                                                         height_shift_range=0.015,
#                                                         brightness_range=None,
#                                                         shear_range=0.02,
#                                                         zoom_range=0.2400,
#                                                         channel_shift_range=0.0,
#                                                         fill_mode="nearest",
#                                                         cval=0.0,
#                                                         horizontal_flip=True,
#                                                         vertical_flip=True,
#                                                         rescale= 1./255,
#                                                         preprocessing_function=None,
#                                                         data_format=None,
#                                                         validation_split=0.25,
#                                                         dtype=None,)
# image = dataset.flow_from_directory('clash_data/train/train/TownHall_8/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_8',class_mode='categorical',save_prefix='deck1',save_format='jpg',batch_size=25)
# image.next()
# dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
#                                                         rotation_range=90,
#                                                         width_shift_range=0.0045,
#                                                         height_shift_range=0.015,
#                                                         brightness_range=None,
#                                                         shear_range=0.02,
#                                                         zoom_range=0.2400,
#                                                         channel_shift_range=0.0,
#                                                         fill_mode="nearest",
#                                                         cval=0.0,
#                                                         horizontal_flip=True,
#                                                         vertical_flip=True,
#                                                         rescale= 1./255,
#                                                         preprocessing_function=None,
#                                                         data_format=None,
#                                                         validation_split=0.25,
#                                                         dtype=None,)
# image = dataset.flow_from_directory('clash_data/train/train/TownHall_7/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_7',class_mode='categorical',save_prefix='deck1',save_format='jpg',batch_size=25)
# image.next()
# dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
#                                                         rotation_range=90,
#                                                         width_shift_range=0.0045,
#                                                         height_shift_range=0.015,
#                                                         brightness_range=None,
#                                                         shear_range=0.02,
#                                                         zoom_range=0.2400,
#                                                         channel_shift_range=0.0,
#                                                         fill_mode="nearest",
#                                                         cval=0.0,
#                                                         horizontal_flip=True,
#                                                         vertical_flip=True,
#                                                         rescale= 1./255,
#                                                         preprocessing_function=None,
#                                                         data_format=None,
#                                                         validation_split=0.25,
#                                                         dtype=None,)
# image = dataset.flow_from_directory('clash_data/train/train/TownHall_6/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/TownHall_6',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
# image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        brightness_range=None,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,
                                                        dtype=None,)
image = dataset.flow_from_directory('clash_data/train/train/Builder_Hall/BuilderBase_Th9Farm/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/Builder_Hall/BuilderBase_Th9Farm/attacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
# image = dataset.flow_from_directory('clash_data/train/train/Builder_Hall/BuilderBase_Th8Farm/Attacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/Builder_Hall',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
# image.next() 
image = dataset.flow_from_directory('clash_data/train/train/Builder_Hall/BuilderBase_Th9Farm/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/Builder_Hall/BuilderBase_Th9Farm/Unattacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
image = dataset.flow_from_directory('clash_data/train/train/Builder_Hall/BuilderBase_Th8Farm/Unattacked/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/Builder_Hall/BuilderBase_Th8Farm/Unattacked/',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
image.next()
# dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
#                                                         rotation_range=90,
#                                                         width_shift_range=0.0045,
#                                                         height_shift_range=0.015,
#                                                         brightness_range=None,
#                                                         shear_range=0.02,
#                                                         zoom_range=0.2400,
#                                                         channel_shift_range=0.0,
#                                                         fill_mode="nearest",
#                                                         cval=0.0,
#                                                         horizontal_flip=True,
#                                                         vertical_flip=True,
#                                                         rescale= 1./255,
#                                                         preprocessing_function=None,
#                                                         data_format=None,
#                                                         validation_split=0.25,
#                                                         dtype=None,)
# image = dataset.flow_from_directory('clash_data/train/train/Fun_Bases/',shuffle=False,target_size=(255,255),save_to_dir='clash_data/validation/validation/Fun_Bases',class_mode='categorical',save_prefix='clash_',save_format='jpg',batch_size=25)
# image.next()
# Out:
#   File "<ipython-input-25-577c25c6ac6f>", line 7
#     width_shift_range=0.0.025,
#                             ^
# SyntaxError: invalid syntax

# %%
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/Builder_Hall/BuilderBase_Th9Farm/',target_size=(255,255),save_to_dir='clash_data/test/test/Builder_Hall/Builder_Hall/BuilderBase_Th9Farm/',class_mode='binary',save_prefix='N',save_format='jpeg',batch_size=10)
image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/Builder_Hall/BuilderBase_Th8Farm/',target_size=(255,255),save_to_dir='clash_data/test/test/Builder_Hall/Builder_Hall/BuilderBase_Th8Farm/',class_mode='binary',save_prefix='N',save_format='jpeg',batch_size=10)
image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_10/Farm/',target_size=(255,255),save_to_dir='clash_data/test/test/TownHall_10/',class_mode='binary',save_prefix='N',save_format='jpeg',batch_size=10)
image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_10/Trophy/',target_size=(255,255),save_to_dir='clash_data/test/test/TownHall_10/',class_mode='binary',save_prefix='N',save_format='jpeg',batch_size=10)
image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_11/farm/',target_size=(255,255),save_to_dir='clash_data/test/test/TownHall_11/',class_mode='binary',save_prefix='N',save_format='jpeg',batch_size=10)
image.next()


dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_11/War/',target_size=(255,255),save_to_dir='clash_data/test/test/TownHall_11/',class_mode='binary',save_prefix='N',save_format='jpeg',batch_size=10)
image.next()

dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_12/Farm/',target_size=(255,255),save_to_dir='clash_data/test/test/TownHall_11/',class_mode='binary',save_prefix='N',save_format='jpeg',batch_size=10)
image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_12/War/',target_size=(255,255),save_to_dir='clash_data/test/test/TownHall_11/',class_mode='binary',save_prefix='N',save_format='jpeg',batch_size=10)
image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_12/Trophy/',target_size=(255,255),save_to_dir='clash_data/test/test/TownHall_11/',class_mode='binary',save_prefix='N',save_format='jpeg',batch_size=10)
image.next()
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/TownHall_13/farm',target_size=(255,255),save_to_dir='clash_data/test/test/TownHall_11/',class_mode='binary',save_prefix='N',save_format='jpeg',batch_size=10)
image.next()
# Out:
# Found 30 images belonging to 2 classes.
# Found 4 images belonging to 2 classes.
# Found 11 images belonging to 2 classes.
# Found 9 images belonging to 2 classes.
# Found 12 images belonging to 2 classes.
# Found 17 images belonging to 2 classes.
# Found 3 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.
# Found 11 images belonging to 1 classes.
# Found 43 images belonging to 2 classes.
# (array([[[[0.49411768, 0.43921572, 0.2627451 ],
#           [0.48235297, 0.43921572, 0.24313727],
#           [0.46274513, 0.43529415, 0.19215688],
#           ...,
#           [0.14901961, 0.07843138, 0.07450981],
#           [0.15294118, 0.08235294, 0.07450981],
#           [0.16078432, 0.09019608, 0.08235294]],
#
#          [[0.49411768, 0.43921572, 0.2627451 ],
#           [0.49411768, 0.43921572, 0.2627451 ],
#           [0.48235297, 0.43921572, 0.24313727],
#           ...,
#           [0.15294118, 0.08235294, 0.07450981],
# ...

# %%
dataset = keras.preprocessing.image.ImageDataGenerator(samplewise_std_normalization=False,
                                                        rotation_range=90,
                                                        width_shift_range=0.0045,
                                                        height_shift_range=0.015,
                                                        shear_range=0.02,
                                                        zoom_range=0.003500,
                                                        channel_shift_range=0.0,
                                                        fill_mode="nearest",
                                                        cval=0.0,
                                                        horizontal_flip=True,
                                                        vertical_flip=True,
                                                        rescale= 1./255,)
image = dataset.flow_from_directory('clash_data/train/train/',target_size=(255,255),save_to_dir='clash_data/test/test',class_mode='binary',save_prefix='N',save_format='jpeg',batch_size=10)
image.next()
# Out:
# Found 160 images belonging to 11 classes.
# (array([[[[0.227451  , 0.10980393, 0.09019608],
#           [0.21568629, 0.10196079, 0.07843138],
#           [0.20784315, 0.09411766, 0.07058824],
#           ...,
#           [0.25882354, 0.16470589, 0.13333334],
#           [0.2627451 , 0.15686275, 0.12941177],
#           [0.2627451 , 0.15686275, 0.12941177]],
#
#          [[0.227451  , 0.10980393, 0.09019608],
#           [0.21568629, 0.10196079, 0.07843138],
#           [0.21568629, 0.10196079, 0.07843138],
#           ...,
#           [0.2627451 , 0.15686275, 0.12941177],
#           [0.2784314 , 0.16078432, 0.14117648],
#           [0.2784314 , 0.16078432, 0.14117648]],
#
#          [[0.24313727, 0.1137255 , 0.09411766],
#           [0.227451  , 0.10980393, 0.09019608],
#           [0.21568629, 0.10196079, 0.07843138],
#           ...,
#           [0.2784314 , 0.16078432, 0.14117648],
#           [0.2784314 , 0.16078432, 0.14117648],
# ...
